# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jorda\\Documents\\GitHub\\OOP-Final_Project\\1 - Final Project\\JupyterNotebook'

# %%
import sys
sys.path.append('C:\\Users\\jorda\\Documents\\GitHub\\OOP-Final_Project\\1 - Final Project\\JupyterNotebook')  # i-change sa imong path

# %%
import sys
import os

# Path sa folder kung asa naa ang datamedic
sys.path.append(os.path.abspath("C:/Users/yourname/Documents/GitHub/your_repo/"))

# %%
from datamedic import DataDoctor, DataInspector, ReportGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from datamedic import DataDoctor, DataInspector, ReportGenerator
#
# ModuleNotFoundError: No module named 'datamedic'
